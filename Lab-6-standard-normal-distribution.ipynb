# %% [markdown]
# ## <b>Z-SCORE<hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>

# %% [markdown]
# <b>AG D. Evangelista</b><br>
# Comptech Student T09<br>
# 1/20/2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.DataFrame([1,2,2,3,3,3,4,4,5],
                  columns=['Dataset'])

df
# Out:
#    Dataset
# 0        1
# 1        2
# 2        2
# 3        3
# 4        3
# 5        3
# 6        4
# 7        4
# 8        5

# %%
df.describe().round(2)
# Out:
#        Dataset
# count     9.00
# mean      3.00
# std       1.22
# min       1.00
# 25%       2.00
# 50%       3.00
# 75%       4.00
# max       5.00

# %%
df['Z-Score'] = stats.zscore(df['Dataset'],ddof=1)
df.round(2)
# Out:
#    Dataset  Z-Score
# 0        1    -1.63
# 1        2    -0.82
# 2        2    -0.82
# 3        3     0.00
# 4        3     0.00
# 5        3     0.00
# 6        4     0.82
# 7        4     0.82
# 8        5     1.63

# %%
df['Z-Score'].mean()
# Out:
# 0.0

# %%
df = pd.read_csv(r"dataset\current-test.csv",
                 delimiter=',',
                 index_col=0)
df.head()
# Out:
#         Current
# Sample
# 1          12.0
# 2          15.0
# 3           8.3
# 4           9.7
# 5          12.0

# %%
df['Current'][2]
# Out:
# 15.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1 to 30
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Current  30 non-null     float64
#  1   Z-score  30 non-null     float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
df.describe()
# Out:
#          Current       Z-score
# count  30.000000  3.000000e+01
# mean   11.806667  7.401487e-18
# std     3.166629  1.000000e+00
# min     3.300000 -2.686348e+00
# 25%    10.250000 -4.915848e-01
# 50%    12.000000  6.105335e-02
# 75%    13.775000  6.215863e-01
# max    21.500000  3.061089e+00

# %%
df['Z-score'] = stats.zscore(df['Current'], ddof=1)
df
# Out:
#         Current   Z-score
# Sample
# 1          12.0  0.061053
# 2          15.0  1.008433
# 3           8.3 -1.107382
# 4           9.7 -0.665271
# 5          12.0  0.061053
# 6          13.9  0.661060
# 7          14.1  0.724219
# 8           9.2 -0.823168
# 9          12.4  0.187371
# 10         13.7  0.597902
# 11         10.6 -0.381057
# 12         21.5  3.061089
# 13         12.0  0.061053
# 14          9.3 -0.791588
# 15         11.2 -0.191581
# 16          3.3 -2.686348
# 17         12.4  0.187371
# 18         12.3  0.155791
# 19         13.8  0.629481
# 20         10.5 -0.412636
# 21         10.4 -0.444216
# 22         15.0  1.008433
# 23         12.7  0.282109
# 24         14.4  0.818957
# 25         11.0 -0.254740
# 26          9.1 -0.854747
# 27         10.2 -0.507374
# 28         12.4  0.187371
# 29          7.0 -1.517913
# 30         14.8  0.945274

# %%
df['Z-score'].describe().round(1)
# Out:
# count    30.0
# mean      0.0
# std       1.0
# min      -2.7
# 25%      -0.5
# 50%       0.1
# 75%       0.6
# max       3.1
# Name: Z-score, dtype: float64

# %% [markdown]
# ## <b>HISTOGRAM<hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>

# %%
plt.hist(df['Current'], bins=5,
         alpha=0.7,
         color="#FF0000",
         edgecolor='black')

plt.title('Current Distribution Histogram',
          fontsize=14,
          fontfamily='Sans-Serif',
          fontweight='bold')
plt.xlabel('Current (A)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# ## <b>NORMAL DISTRIBUTION<hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>

# %%
mean=df['Current'].mean()
std=df['Current'].std(ddof=1)

x_min = df['Current'].min()
x_max = df['Current'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)

plt.plot(x, p, 'k', color='red', linewidth=2)
plt.title('Current Distribution Curve',
            fontsize=14,
            fontfamily='Sans-Serif',
            fontweight='bold')
plt.xlabel('Current (A)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()
# Out:
# C:\Users\evang\AppData\Local\Temp\ipykernel_15864\1728574889.py:10: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k" (-> color=(0.0, 0.0, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(x, p, 'k', color='red', linewidth=2)
