# %% [markdown]
# ## Numpy Basics <hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>

# %% [markdown]
# <b>AG D. Evangelista</b><br>
# Comptech Student T09

# %%
#imports and packages
import numpy as np

# %%
my_array = np.array([1,2,3])
my_array
# Out:
# array([1, 2, 3])

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# ## 2D Array <hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>

# %%
my_array = np.array([
    [1,2,3],
    [4,5,6]
])

my_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.shape(my_array)
# Out:
# (2, 3)

# %%
t_array = my_array.T
t_array
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
np.shape(t_array)
# Out:
# (3, 2)

# %% [markdown]
# ## MEASURES OF CENTRAL TENDENCY <hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>
