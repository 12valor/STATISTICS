# %% [markdown]
# ## <b>z-DISTRIBUTION<hr style="border:2.5px solid rgba(255, 0, 0, 1)"></hr>

# %% [markdown]
# <b>AG D. Evangelista</b><br>
# Comptech Student T09<br>
# 1/27/2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv(r"dataset\transformer-voltage.csv",
                 delimiter=',',
                 index_col=0)
df.head()
# Out:
#         Voltage
# Sample
# 1         117.0
# 2         118.3
# 3         119.5
# 4         119.5
# 5         119.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1 to 30
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Voltage  30 non-null     float64
# dtypes: float64(1)
# memory usage: 480.0 bytes

# %%
df.describe()
# Out:
#           Voltage
# count   30.000000
# mean   120.290000
# std      1.243285
# min    117.000000
# 25%    119.700000
# 50%    120.100000
# 75%    120.500000
# max    123.800000

# %%
alpha = 0.05
z_critical = stats.norm.ppf(1 - alpha/2)
z_critical
# Out:
# 1.959963984540054

# %%
pop_std = 5

cl_lower, cl_upper = stats.norm.interval(
    confidence=0.95,
    loc = df['Voltage'].mean(),
    scale = pop_std/np.sqrt(df['Voltage'].count())
)

print("CI =", [cl_lower, cl_upper])
# Out:
# CI = [118.50080585628282, 122.07919414371713]

# %%
mean = df['Voltage'].mean()
std = df['Voltage'].std(ddof=1)

x_min = df['Voltage'].min()
x_max = df['Voltage'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)
plt.plot(x, p,
         linewidth = 2,
         color="red")

plt.hist(df['Voltage'],
         bins=5,
         density=True,
         alpha=0.6,
         color="blue")
# Out:
# (array([0.04901961, 0.17156863, 0.36764706, 0.09803922, 0.04901961]),
#  array([117.  , 118.36, 119.72, 121.08, 122.44, 123.8 ]),
#  <BarContainer object of 5 artists>)
